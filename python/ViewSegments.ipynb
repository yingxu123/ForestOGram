# %%
import matplotlib.pyplot as plt
import ProcessSegments as PSeg

# %%
segments = PSeg.process_data()

# %%
_,num_a,_,_ = PSeg.load_data()

fig = plt.figure()
plt.plot(num_a)
plt.show()

# %%
all_segs = []
for seg in segments:
    fig = plt.figure()
    plt.plot(seg)
    plt.show()
    all_segs.extend(seg)

# %%
fig = plt.figure()
plt.plot(all_segs)
plt.show()
