# %%
import matplotlib.pyplot as plt
import ProcessSegments as PSeg

# %%
segments = PSeg.process_data()

# %%
_,num_a,_,_ = PSeg.load_data()

# %%
all_segs = []
for seg in segments:
    all_segs.extend(seg)

# %%
fig = plt.figure()
plt.plot(all_segs,label="ying_onset_offset")
plt.plot(num_a,label="original Pink Pigeon")
plt.legend()
plt.show()
